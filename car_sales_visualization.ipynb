# %%
pip install dash plotly pandas
# Out:
# Collecting dashNote: you may need to restart the kernel to use updated packages.
#
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.2.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from dash) (3.0.3)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from dash) (2.31.0)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from dash) (70.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from plotly) (1.27.1)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from plotly) (24.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Collecting zipp>=3.20 (from importlib-metadata->dash)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests->dash) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests->dash) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests->dash) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.8 MB 1.3 MB/s eta 0:00:06
#     --------------------------------------- 0.2/7.8 MB 1.8 MB/s eta 0:00:05
#    -- ------------------------------------- 0.4/7.8 MB 3.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/7.8 MB 3.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.8 MB 5.3 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.8 MB 5.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.8 MB 6.4 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/7.8 MB 7.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.2/7.8 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/7.8 MB 7.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.7/7.8 MB 7.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.7/7.8 MB 7.9 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.8 MB 6.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.6/7.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------- -------------- 4.9/7.8 MB 7.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.1/7.8 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 5.1/7.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.8 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.8 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 5.9/7.8 MB 6.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.8 MB 6.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/7.8 MB 6.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.8 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 6.5/7.8 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.8 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.9/7.8 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.0/7.8 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/7.8 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 5.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.4/7.8 MB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 4.8 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/14.8 MB 2.6 MB/s eta 0:00:06
#     --------------------------------------- 0.2/14.8 MB 3.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/14.8 MB 3.0 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/14.8 MB 3.0 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/14.8 MB 2.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/14.8 MB 3.0 MB/s eta 0:00:05
#    -- ------------------------------------- 0.9/14.8 MB 3.0 MB/s eta 0:00:05
#    -- ------------------------------------- 1.1/14.8 MB 3.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.2/14.8 MB 2.9 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/14.8 MB 2.9 MB/s eta 0:00:05
#    --- ------------------------------------ 1.4/14.8 MB 2.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/14.8 MB 2.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.7/14.8 MB 2.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.8/14.8 MB 2.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.9/14.8 MB 2.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.9/14.8 MB 2.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.0/14.8 MB 2.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.1/14.8 MB 2.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.2/14.8 MB 2.5 MB/s eta 0:00:06
#    ------ --------------------------------- 2.3/14.8 MB 2.5 MB/s eta 0:00:06
#    ------ --------------------------------- 2.4/14.8 MB 2.4 MB/s eta 0:00:06
#    ------ --------------------------------- 2.5/14.8 MB 2.4 MB/s eta 0:00:06
#    ------ --------------------------------- 2.5/14.8 MB 2.4 MB/s eta 0:00:06
#    ------- -------------------------------- 2.6/14.8 MB 2.3 MB/s eta 0:00:06
#    ------- -------------------------------- 2.7/14.8 MB 2.3 MB/s eta 0:00:06
#    ------- -------------------------------- 2.8/14.8 MB 2.3 MB/s eta 0:00:06
#    ------- -------------------------------- 2.9/14.8 MB 2.3 MB/s eta 0:00:06
#    -------- ------------------------------- 3.0/14.8 MB 2.2 MB/s eta 0:00:06
#    -------- ------------------------------- 3.0/14.8 MB 2.2 MB/s eta 0:00:06
#    -------- ------------------------------- 3.2/14.8 MB 2.2 MB/s eta 0:00:06
#    -------- ------------------------------- 3.3/14.8 MB 2.2 MB/s eta 0:00:06
#    --------- ------------------------------ 3.3/14.8 MB 2.2 MB/s eta 0:00:06
#    --------- ------------------------------ 3.4/14.8 MB 2.2 MB/s eta 0:00:06
#    --------- ------------------------------ 3.5/14.8 MB 2.2 MB/s eta 0:00:06
#    --------- ------------------------------ 3.6/14.8 MB 2.2 MB/s eta 0:00:06
#    --------- ------------------------------ 3.7/14.8 MB 2.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.8/14.8 MB 2.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.9/14.8 MB 2.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 4.0/14.8 MB 2.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.1/14.8 MB 2.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.2/14.8 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.2/14.8 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.4/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 4.5/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 4.5/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 4.7/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 4.7/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 4.8/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 4.9/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 5.0/14.8 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 5.1/14.8 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.2/14.8 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.3/14.8 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.4/14.8 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.4/14.8 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 5.6/14.8 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 5.7/14.8 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 5.8/14.8 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 5.9/14.8 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.0/14.8 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.0/14.8 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.1/14.8 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.3/14.8 MB 2.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.3/14.8 MB 2.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.4/14.8 MB 2.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.5/14.8 MB 2.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.6/14.8 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.6/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 6.7/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 6.8/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 7.0/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------- -------------------- 7.1/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------- -------------------- 7.3/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------- -------------------- 7.4/14.8 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.5/14.8 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.5/14.8 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.6/14.8 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.7/14.8 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 7.8/14.8 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 7.9/14.8 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 8.0/14.8 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 8.1/14.8 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.2/14.8 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.3/14.8 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.4/14.8 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.5/14.8 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 8.6/14.8 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 8.7/14.8 MB 2.0 MB/s eta 0:00:04
#    ------------------------ --------------- 8.9/14.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 9.0/14.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 9.2/14.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 9.4/14.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 9.5/14.8 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 9.7/14.8 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 9.8/14.8 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 10.0/14.8 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 10.1/14.8 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 10.3/14.8 MB 2.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.5/14.8 MB 2.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.6/14.8 MB 2.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.7/14.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 10.8/14.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 10.9/14.8 MB 1.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.0/14.8 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.1/14.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 11.2/14.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 11.3/14.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 11.5/14.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------- -------- 11.6/14.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------- -------- 11.6/14.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------- -------- 11.8/14.8 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 11.9/14.8 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 12.0/14.8 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 12.1/14.8 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 12.2/14.8 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 12.3/14.8 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 12.4/14.8 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 12.5/14.8 MB 1.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.6/14.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.8/14.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.8/14.8 MB 2.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.0/14.8 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.1/14.8 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.1/14.8 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.3/14.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 13.4/14.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 13.5/14.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.7/14.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.8/14.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.1/14.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.3/14.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  14.6/14.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  14.8/14.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 2.0 MB/s eta 0:00:00
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zipp, retrying, plotly, importlib-metadata, dash
# Successfully installed dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 importlib-metadata-8.6.1 plotly-6.0.0 retrying-1.3.4 zipp-3.21.0
# [notice] A new release of pip is available: 24.1.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

# Load dataset
file_path = "car_price_dataset.csv"
df = pd.read_csv(file_path)

# Initialize Dash app
app = dash.Dash(__name__)

# Dropdown options
brands = df["Brand"].unique()

# Layout
app.layout = html.Div([
    html.H1("Car Price Analysis Dashboard"),
    
    dcc.Dropdown(
        id='brand-filter',
        options=[{'label': brand, 'value': brand} for brand in brands],
        multi=True,
        placeholder="Select brands"
    ),
    
    dcc.Graph(id='price-distribution'),
    dcc.Graph(id='average-price-brand'),
    dcc.Graph(id='mileage-price'),
    dcc.Graph(id='fuel-price'),
    dcc.Graph(id='engine-price')
])

# Callbacks for interactivity
@app.callback(
    dash.dependencies.Output('price-distribution', 'figure'),
    [dash.dependencies.Input('brand-filter', 'value')]
)
def update_price_distribution(selected_brands):
    filtered_df = df[df['Brand'].isin(selected_brands)] if selected_brands else df
    fig = px.histogram(filtered_df, x='Price', nbins=50, title='Price Distribution')
    return fig

@app.callback(
    dash.dependencies.Output('average-price-brand', 'figure'),
    [dash.dependencies.Input('brand-filter', 'value')]
)
def update_avg_price(selected_brands):
    filtered_df = df[df['Brand'].isin(selected_brands)] if selected_brands else df
    fig = px.bar(filtered_df.groupby('Brand', as_index=False).mean(), x='Brand', y='Price', title='Average Price by Brand')
    return fig

@app.callback(
    dash.dependencies.Output('mileage-price', 'figure'),
    [dash.dependencies.Input('brand-filter', 'value')]
)
def update_mileage_price(selected_brands):
    filtered_df = df[df['Brand'].isin(selected_brands)] if selected_brands else df
    fig = px.scatter(filtered_df, x='Mileage', y='Price', title='Mileage vs Price')
    return fig

@app.callback(
    dash.dependencies.Output('fuel-price', 'figure'),
    [dash.dependencies.Input('brand-filter', 'value')]
)
def update_fuel_price(selected_brands):
    filtered_df = df[df['Brand'].isin(selected_brands)] if selected_brands else df
    fig = px.box(filtered_df, x='Fuel_Type', y='Price', title='Price by Fuel Type')
    return fig

@app.callback(
    dash.dependencies.Output('engine-price', 'figure'),
    [dash.dependencies.Input('brand-filter', 'value')]
)
def update_engine_price(selected_brands):
    filtered_df = df[df['Brand'].isin(selected_brands)] if selected_brands else df
    fig = px.scatter(filtered_df, x='Engine_Size', y='Price', title='Engine Size vs Price')
    return fig

# Run app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(
#     self=<pandas.core.groupby.generic.DataFrameGroupBy object>,
#     how='mean',
#     values=array([['Rio', 'Malibu', 'GLA', ..., '3 Series', 'Explorer', 'Tiguan']],
#       dtype=object),
#     ndim=2,
#     alt=<function GroupBy.mean.<locals>.<lambda>>
# )
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#         alt = <function GroupBy.mean.<locals>.<lambda> at 0x0000021A25658900>
#         ser = 0            Rio
# 1         Malibu
# 2            GLA
# 3             Q5
# 4           Golf
#           ...
# 9995      Optima
# 9996      Impala
# 9997    3 Series
# 9998    Explorer
# 9999      Tiguan
# Name: 0, Length: 10000, dtype: object
#         self._grouper = <pandas.core.groupby.ops.BaseGrouper object at 0x0000021A256B3A40>
#         self = <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000021A24ABF110>
#    1943 except Exception as err:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(
#     self=<pandas.core.groupby.ops.BaseGrouper object>,
#     obj=0            Rio
# 1         Malibu
# 2            G...     Tiguan
# Name: 0, Length: 10000, dtype: object,
#     func=<function GroupBy.mean.<locals>.<lambda>>,
#     preserve_dtype=True
# )
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#         obj = 0            Rio
# 1         Malibu
# 2            GLA
# 3             Q5
# 4           Golf
#           ...
# 9995      Optima
# 9996      Impala
# 9997    3 Series
# 9998    Explorer
# 9999      Tiguan
# Name: 0, Length: 10000, dtype: object
#         func = <function GroupBy.mean.<locals>.<lambda> at 0x0000021A25658900>
#         self = <pandas.core.groupby.ops.BaseGrouper object at 0x0000021A256B3A40>
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(
#     self=<pandas.core.groupby.ops.BaseGrouper object>,
#     obj=0            Rio
# 1         Malibu
# 2            G...     Tiguan
# Name: 0, Length: 10000, dtype: object,
#     func=<function GroupBy.mean.<locals>.<lambda>>
# )
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#         group = 3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44      Q5
#         ..
# 9961    A4
# 9968    A3
# 9985    A4
# 9986    A4
# 9990    A3
# Name: 0, Length: 1038, dtype: object
#         func = <function GroupBy.mean.<locals>.<lambda> at 0x0000021A25658900>
#     886     res = extract_result(res)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(
#     x=3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44  ...4
# 9990    A3
# Name: 0, Length: 1038, dtype: object
# )
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#         numeric_only = False
#         x = 3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44      Q5
#         ..
# 9961    A4
# 9968    A3
# 9985    A4
# 9986    A4
# 9990    A3
# Name: 0, Length: 1038, dtype: object
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6540, in Series.mean(
#     self=3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44  ...4
# 9990    A3
# Name: 0, Length: 1038, dtype: object,
#     axis=0,
#     skipna=True,
#     numeric_only=False,
#     **kwargs={}
# )
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#         self = 3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44      Q5
#         ..
# 9961    A4
# 9968    A3
# 9985    A4
# 9986    A4
# 9990    A3
# Name: 0, Length: 1038, dtype: object
#         axis = 0
#         skipna = True
#         numeric_only = False
#         kwargs = {}
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12417, in NDFrame.mean(
#     self=3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44  ...4
# 9990    A3
# Name: 0, Length: 1038, dtype: object,
#     axis=0,
#     skipna=True,
#     numeric_only=False,
#     **kwargs={}
# )
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#         self = 3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44      Q5
#         ..
# 9961    A4
# 9968    A3
# 9985    A4
# 9986    A4
# 9990    A3
# Name: 0, Length: 1038, dtype: object
#         axis = 0
#         skipna = True
#         numeric_only = False
#         nanops = <module 'pandas.core.nanops' from 'c:\\Users\\Lenovo\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\core\\nanops.py'>
#         kwargs = {}
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12374, in NDFrame._stat_function(
#     self=3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44  ...4
# 9990    A3
# Name: 0, Length: 1038, dtype: object,
#     name='mean',
#     func=<function nanmean>,
#     axis=0,
#     skipna=True,
#     numeric_only=False,
#     **kwargs={}
# )
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#         self = 3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44      Q5
#         ..
# 9961    A4
# 9968    A3
# 9985    A4
# 9986    A4
# 9990    A3
# Name: 0, Length: 1038, dtype: object
#         name = 'mean'
#         skipna = True
#         func = <function nanmean at 0x0000021A0C44ECA0>
#         axis = 0
#         numeric_only = False
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6448, in Series._reduce(
#     self=3       Q5
# 26      A3
# 36      Q5
# 39      A4
# 44  ...4
# 9990    A3
# Name: 0, Length: 1038, dtype: object,
#     op=<function nanmean>,
#     name='mean',
#     axis=0,
#     skipna=True,
#     numeric_only=False,
#     filter_type=None,
#     **kwds={}
# )
#    6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
# -> 6448 return op(delegate, skipna=skipna, **kwds)
#         delegate = array(['Q5', 'A3', 'Q5', ..., 'A4', 'A4', 'A3'], dtype=object)
#         op = <function nanmean at 0x0000021A0C44ECA0>
#         skipna = True
#         kwds = {}
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(
#     values=array(['Q5', 'A3', 'Q5', ..., 'A4', 'A4', 'A3'], dtype=object),
#     axis=None,
#     skipna=True,
#     **kwds={}
# )
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#         alt = <function nanmean at 0x0000021A0C44EC00>
#         skipna = True
#         values = array(['Q5', 'A3', 'Q5', ..., 'A4', 'A4', 'A3'], dtype=object)
#         axis = None
#         kwds = {}
#     149 return result
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(
#     values=array(['Q5', 'A3', 'Q5', ..., 'A4', 'A4', 'A3'], dtype=object),
#     axis=None,
#     skipna=True,
#     mask=None,
#     **kwargs={}
# )
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#         values = array(['Q5', 'A3', 'Q5', ..., 'A4', 'A4', 'A3'], dtype=object)
#         func = <function nanmean at 0x0000021A0C44EB60>
#         mask = None
#         axis = None
#         skipna = True
#         kwargs = {}
#     406 if datetimelike:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(
#     values=array(['Q5', 'A3', 'Q5', ..., 'A4', 'A4', 'A3'], dtype=object),
#     axis=None,
#     skipna=True,
#     mask=array([False, False, False, ..., False, False, False])
# )
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#         the_sum = '...'
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(
#     x='Q5A3Q5A4Q5A4A3A4Q5A3A4A4A3A4A3Q5A3Q5Q5A4A3A3Q5A3...4A3A4A3A4A4A4A4Q5Q5A4A3Q5A4Q5Q5Q5A4A4Q5A4A3A4A4A3'
# )
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#         x = '...'
#    1702 try:
#
# TypeError: Could not convert string '...' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 50, in update_avg_price(selected_brands=None)
#      44 @app.callback(
#      45     dash.dependencies.Output('average-price-brand', 'figure'),
#      46     [dash.dependencies.Input('brand-filter', 'value')]
#      47 )
#      48 def update_avg_price(selected_brands):
#      49     filtered_df = df[df['Brand'].isin(selected_brands)] if selected_brands else df
# ---> 50     fig = px.bar(filtered_df.groupby('Brand', as_index=False).mean(), x='Brand', y='Price', title='Average Price by Brand')
#         filtered_df =            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# 1        5356      2            3  12092
# 2      231440      4            2  11171
# 3      160971      2            1  11780
# 4      286618      3            3   2867
# ...       ...    ...          ...    ...
# 9995     5794      2            4   8884
# 9996   168000      2            1   6240
# 9997    86664      5            1   9866
# 9998   225772      4            1   4084
# 9999   157882      3            3   3342
#
# [10000 rows x 10 columns]
#         fig = <Figure size 1000x500 with 1 Axes>
#         px = <module 'plotly.express' from 'c:\\Users\\Lenovo\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\plotly\\express\\__init__.py'>
#      51     return fig
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(
#     self=<pandas.core.groupby.generic.DataFrameGroupBy object>,
#     numeric_only=False,
#     engine=None,
#     engine_kwargs=None
# )
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#         self = <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000021A24ABF110>
#         numeric_only = False
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(
#     self=<pandas.core.groupby.generic.DataFrameGroupBy object>,
#     how='mean',
#     alt=<function GroupBy.mean.<locals>.<lambda>>,
#     numeric_only=False,
#     min_count=-1,
#     **kwargs={}
# )
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#         data = BlockManager
# Items: Index(['Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission', 'Mileage',
#        'Doors', 'Owner_Count', 'Price'],
#       dtype='object')
# Axis 1: RangeIndex(start=0, stop=10000, step=1)
# NumpyBlock: slice(0, 1, 1), 1 x 10000, dtype: object
# NumpyBlock: slice(1, 2, 1), 1 x 10000, dtype: int64
# NumpyBlock: slice(2, 3, 1), 1 x 10000, dtype: float64
# NumpyBlock: slice(3, 5, 1), 2 x 10000, dtype: object
# NumpyBlock: slice(5, 9, 1), 4 x 10000, dtype: int64
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(
#     self=BlockManager
# Items: Index(['Model', 'Year', 'Eng...mpyBlock: slice(5, 9, 1), 4 x 10000, dtype: int64,
#     func=<function GroupBy._cython_agg_general.<locals>.array_func>
# )
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#         sb = NumpyBlock: slice(0, 1, 1), 1 x 10000, dtype: object
#         func = <function GroupBy._cython_agg_general.<locals>.array_func at 0x0000021A256E9440>
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(
#     self=NumpyBlock: slice(0, 1, 1), 1 x 10000, dtype: object,
#     func=<function GroupBy._cython_agg_general.<locals>.array_func>,
#     **kwargs={}
# )
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#         func = <function GroupBy._cython_agg_general.<locals>.array_func at 0x0000021A256E9440>
#         self = NumpyBlock: slice(0, 1, 1), 1 x 10000, dtype: object
#         kwargs = {}
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(
#     values=array([['Rio', 'Malibu', 'GLA', ..., '3 Series', 'Explorer', 'Tiguan']],
#       dtype=object)
# )
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#         alt = <function GroupBy.mean.<locals>.<lambda> at 0x0000021A25658900>
#         how = 'mean'
#         values = array([['Rio', 'Malibu', 'GLA', ..., '3 Series', 'Explorer', 'Tiguan']],
#       dtype=object)
#         self = <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000021A24ABF110>
#         data.ndim = 2
#         data = BlockManager
# Items: Index(['Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission', 'Mileage',
#        'Doors', 'Owner_Count', 'Price'],
#       dtype='object')
# Axis 1: RangeIndex(start=0, stop=10000, step=1)
# NumpyBlock: slice(0, 1, 1), 1 x 10000, dtype: object
# NumpyBlock: slice(1, 2, 1), 1 x 10000, dtype: int64
# NumpyBlock: slice(2, 3, 1), 1 x 10000, dtype: float64
# NumpyBlock: slice(3, 5, 1), 2 x 10000, dtype: object
# NumpyBlock: slice(5, 9, 1), 4 x 10000, dtype: int64
#    1996 return result
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(
#     self=<pandas.core.groupby.generic.DataFrameGroupBy object>,
#     how='mean',
#     values=array([['Rio', 'Malibu', 'GLA', ..., '3 Series', 'Explorer', 'Tiguan']],
#       dtype=object),
#     ndim=2,
#     alt=<function GroupBy.mean.<locals>.<lambda>>
# )
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#         msg = 'agg function failed [how->mean,dtype->object]'
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]
