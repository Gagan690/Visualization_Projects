# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
file = 'Phone_usage.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Age  Usage
# 0   25     12
# 1   16      4
# 2   43      3
# 3   59     12
# 4   15      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     50 non-null     int64
#  1   Usage   50 non-null     int64
# dtypes: int64(2)
# memory usage: 932.0 bytes

# %%
df.isnull().sum()
# Out:
# Age      0
# Usage    0
# dtype: int64

# %%
df.describe()
# Out:
#              Age      Usage
# count  50.000000  50.000000
# mean   34.660000  11.540000
# std    13.761244   5.574029
# min    15.000000   2.000000
# 25%    23.000000   8.000000
# 50%    33.500000  12.000000
# 75%    46.000000  15.750000
# max    59.000000  21.000000

# %%
sb.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.hist(df['Usage'], edgecolor='Black')
plt.show()

# %%
plt.scatter(df[['Age']],df['Usage'],marker='+')
plt.xlabel('Age')
plt.ylabel('Usage')
plt.show()

# %%
plt.figure(figsize=(12,8))
sb.boxplot(x='Age',y='Usage',data=df)
plt.show()
